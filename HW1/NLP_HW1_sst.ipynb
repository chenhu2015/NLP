# %%
# !pip install transformers datasets evaluate
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting transformers
#   Downloading transformers-4.22.2-py3-none-any.whl (4.9 MB)
#      |████████████████████████████████| 4.9 MB 5.2 MB/s
# Collecting datasets
#   Downloading datasets-2.5.2-py3-none-any.whl (432 kB)
#      |████████████████████████████████| 432 kB 49.2 MB/s
# Collecting evaluate
#   Downloading evaluate-0.2.2-py3-none-any.whl (69 kB)
#      |████████████████████████████████| 69 kB 2.7 MB/s
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (1.21.6)
# Collecting tokenizers!=0.11.3,<0.13,>=0.11.1
#   Downloading tokenizers-0.12.1-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (6.6 MB)
#      |████████████████████████████████| 6.6 MB 63.8 MB/s
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from transformers) (4.12.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from transformers) (21.3)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (2022.6.2)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.7/dist-packages (from transformers) (4.64.1)
# Collecting huggingface-hub<1.0,>=0.9.0
#   Downloading huggingface_hub-0.10.0-py3-none-any.whl (163 kB)
#      |████████████████████████████████| 163 kB 43.4 MB/s
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers) (3.8.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from transformers) (2.23.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.7/dist-packages (from transformers) (6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.7/dist-packages (from huggingface-hub<1.0,>=0.9.0->transformers) (4.1.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->transformers) (3.0.9)
# Requirement already satisfied: pyarrow>=6.0.0 in /usr/local/lib/python3.7/dist-packages (from datasets) (6.0.1)
# Collecting xxhash
#   Downloading xxhash-3.0.0-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (212 kB)
#      |████████████████████████████████| 212 kB 17.2 MB/s
# Collecting responses<0.19
#   Downloading responses-0.18.0-py3-none-any.whl (38 kB)
# Collecting multiprocess
#   Downloading multiprocess-0.70.13-py37-none-any.whl (115 kB)
#      |████████████████████████████████| 115 kB 72.2 MB/s
# Requirement already satisfied: fsspec[http]>=2021.11.1 in /usr/local/lib/python3.7/dist-packages (from datasets) (2022.8.2)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.7/dist-packages (from datasets) (3.8.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from datasets) (1.3.5)
# Requirement already satisfied: dill<0.3.6 in /usr/local/lib/python3.7/dist-packages (from datasets) (0.3.5.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets) (22.1.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets) (1.2.0)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets) (4.0.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets) (2.1.1)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets) (1.8.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets) (6.0.2)
# Requirement already satisfied: asynctest==0.13.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets) (0.13.0)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2022.6.15)
# Collecting urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1
#   Downloading urllib3-1.25.11-py2.py3-none-any.whl (127 kB)
#      |████████████████████████████████| 127 kB 72.1 MB/s
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->transformers) (3.8.1)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas->datasets) (2022.2.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas->datasets) (1.15.0)
# Installing collected packages: urllib3, xxhash, responses, multiprocess, huggingface-hub, tokenizers, datasets, transformers, evaluate
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.24.3
#     Uninstalling urllib3-1.24.3:
#       Successfully uninstalled urllib3-1.24.3
# Successfully installed datasets-2.5.2 evaluate-0.2.2 huggingface-hub-0.10.0 multiprocess-0.70.13 responses-0.18.0 tokenizers-0.12.1 transformers-4.22.2 urllib3-1.25.11 xxhash-3.0.0

# %%
from datasets import load_dataset
raw_datasets = load_dataset("glue","sst2")
# Out:
# Downloading builder script:   0%|          | 0.00/28.8k [00:00<?, ?B/s]
# Downloading metadata:   0%|          | 0.00/28.7k [00:00<?, ?B/s]
# Downloading and preparing dataset glue/sst2 (download: 7.09 MiB, generated: 4.81 MiB, post-processed: Unknown size, total: 11.90 MiB) to /root/.cache/huggingface/datasets/glue/sst2/1.0.0/dacbe3125aa31d7f70367a07a8a9e72a5a0bfeb5fc42e75c9db75b96da6053ad...
# Downloading data:   0%|          | 0.00/7.44M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/67349 [00:00<?, ? examples/s]
# Generating validation split:   0%|          | 0/872 [00:00<?, ? examples/s]
# Generating test split:   0%|          | 0/1821 [00:00<?, ? examples/s]
# Dataset glue downloaded and prepared to /root/.cache/huggingface/datasets/glue/sst2/1.0.0/dacbe3125aa31d7f70367a07a8a9e72a5a0bfeb5fc42e75c9db75b96da6053ad. Subsequent calls will reuse this data.
#   0%|          | 0/3 [00:00<?, ?it/s]

# %%
raw_datasets["test"][0]
# Out:
# {'sentence': 'uneasy mishmash of styles and genres .', 'label': -1, 'idx': 0}

# %%
raw_datasets["validation"][0]
# Out:
# {'sentence': "it 's a charming and often affecting journey . ",
#  'label': 1,
#  'idx': 0}

# %%
raw_datasets["train"][0]
# Out:
# {'sentence': 'hide new secretions from the parental units ',
#  'label': 0,
#  'idx': 0}

# %%
from transformers import AutoTokenizer
tokenizer = AutoTokenizer.from_pretrained("bert-base-uncased")
# Out:
# Downloading:   0%|          | 0.00/28.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/570 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/466k [00:00<?, ?B/s]

# %%
def tokenize_function(examples):
  return tokenizer(examples["sentence"], truncation=True)

# %%
tokenized_datasets = raw_datasets.map(tokenize_function,batched=True)

from transformers import DataCollatorWithPadding

data_collator = DataCollatorWithPadding(tokenizer=tokenizer)
# Out:
#   0%|          | 0/68 [00:00<?, ?ba/s]
#   0%|          | 0/1 [00:00<?, ?ba/s]
#   0%|          | 0/2 [00:00<?, ?ba/s]

# %%
from transformers import AutoModelForSequenceClassification, TrainingArguments, Trainer

model = AutoModelForSequenceClassification.from_pretrained("bert-base-uncased", num_labels=2)
# Out:
# Downloading:   0%|          | 0.00/440M [00:00<?, ?B/s]
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing BertForSequenceClassification: ['cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.decoder.weight', 'cls.seq_relationship.bias', 'cls.seq_relationship.weight', 'cls.predictions.bias', 'cls.predictions.transform.dense.bias', 'cls.predictions.transform.dense.weight']
# - This IS expected if you are initializing BertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
import numpy as np
import evaluate

def compute_metrics(eval_preds):
    metric = evaluate.load("glue","sst2")
    logits, labels = eval_preds
    predictions = np.argmax(logits, axis=-1)
    return metric.compute(predictions=predictions, references=labels)

# %%
'''
training_args = TrainingArguments(
    output_dir="./results",
    learning_rate=2e-4,
    per_device_train_batch_size=16,
    per_device_eval_batch_size=16,
    num_train_epochs=5,
    weight_decay=0.01,
    evaluation_strategy="steps"
)
'''

training_args = TrainingArguments("test-trainer")
training_args = TrainingArguments(
    output_dir="./results2",
    num_train_epochs=5,
    evaluation_strategy="steps")

trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=tokenized_datasets["train"],
    eval_dataset=tokenized_datasets["validation"],
    tokenizer=tokenizer,
    data_collator=data_collator,
    compute_metrics=compute_metrics,
)

trainer.train()
# Out:
# The following columns in the training set don't have a corresponding argument in `BertForSequenceClassification.forward` and have been ignored: sentence, idx. If sentence, idx are not expected by `BertForSequenceClassification.forward`,  you can safely ignore this message.
# /usr/local/lib/python3.7/dist-packages/transformers/optimization.py:310: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   FutureWarning,
# ***** Running training *****
#   Num examples = 67349
#   Num Epochs = 5
#   Instantaneous batch size per device = 8
#   Total train batch size (w. parallel, distributed & accumulation) = 8
#   Gradient Accumulation steps = 1
#   Total optimization steps = 42095
# You're using a BertTokenizerFast tokenizer. Please note that with a fast tokenizer, using the `__call__` method is faster than using a method to encode the text followed by a call to the `pad` method to get a padded encoding.
#     <div>
#
#       <progress value='42095' max='42095' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [42095/42095 1:16:29, Epoch 5/5]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>500</td>
#       <td>0.442100</td>
#       <td>0.340210</td>
#       <td>0.865826</td>
#     </tr>
#     <tr>
#       <td>1000</td>
#       <td>0.375700</td>
#       <td>0.489562</td>
#       <td>0.853211</td>
#     </tr>
#     <tr>
#       <td>1500</td>
#       <td>0.342900</td>
#       <td>0.382470</td>
#       <td>0.885321</td>
#     </tr>
#     <tr>
#       <td>2000</td>
#       <td>0.333700</td>
#       <td>0.322717</td>
#       <td>0.887615</td>
#     </tr>
#     <tr>
#       <td>2500</td>
#       <td>0.332100</td>
#       <td>0.339695</td>
#       <td>0.881881</td>
#     </tr>
#     <tr>
#       <td>3000</td>
#       <td>0.356400</td>
#       <td>0.314560</td>
#       <td>0.864679</td>
#     </tr>
#     <tr>
#       <td>3500</td>
#       <td>0.324700</td>
#       <td>0.463942</td>
#       <td>0.876147</td>
#     </tr>
#     <tr>
#       <td>4000</td>
#       <td>0.305200</td>
#       <td>0.442011</td>
#       <td>0.844037</td>
#     </tr>
#     <tr>
#       <td>4500</td>
#       <td>0.295100</td>
#       <td>0.466947</td>
#       <td>0.876147</td>
#     </tr>
#     <tr>
#       <td>5000</td>
#       <td>0.306500</td>
#       <td>0.449484</td>
#       <td>0.855505</td>
#     </tr>
#     <tr>
#       <td>5500</td>
#       <td>0.303600</td>
#       <td>0.341173</td>
#       <td>0.894495</td>
#     </tr>
#     <tr>
#       <td>6000</td>
#       <td>0.282600</td>
#       <td>0.375390</td>
#       <td>0.895642</td>
#     </tr>
#     <tr>
#       <td>6500</td>
#       <td>0.295500</td>
#       <td>0.431999</td>
#       <td>0.869266</td>
#     </tr>
#     <tr>
#       <td>7000</td>
#       <td>0.286600</td>
#       <td>0.424220</td>
#       <td>0.877294</td>
#     </tr>
#     <tr>
#       <td>7500</td>
#       <td>0.285400</td>
#       <td>0.323557</td>
#       <td>0.900229</td>
#     </tr>
#     <tr>
#       <td>8000</td>
#       <td>0.269500</td>
#       <td>0.413309</td>
#       <td>0.896789</td>
#     </tr>
#     <tr>
#       <td>8500</td>
#       <td>0.274300</td>
#       <td>0.492572</td>
#       <td>0.888761</td>
#     </tr>
#     <tr>
#       <td>9000</td>
#       <td>0.194500</td>
#       <td>0.590048</td>
#       <td>0.877294</td>
#     </tr>
#     <tr>
#       <td>9500</td>
#       <td>0.216200</td>
#       <td>0.431400</td>
#       <td>0.899083</td>
#     </tr>
#     <tr>
#       <td>10000</td>
#       <td>0.199900</td>
#       <td>0.462303</td>
#       <td>0.893349</td>
#     </tr>
#     <tr>
#       <td>10500</td>
#       <td>0.206900</td>
#       <td>0.514788</td>
#       <td>0.871560</td>
#     </tr>
#     <tr>
#       <td>11000</td>
#       <td>0.214300</td>
#       <td>0.410352</td>
#       <td>0.900229</td>
#     </tr>
#     <tr>
#       <td>11500</td>
#       <td>0.200600</td>
#       <td>0.566234</td>
#       <td>0.871560</td>
#     </tr>
#     <tr>
#       <td>12000</td>
#       <td>0.203700</td>
#       <td>0.666419</td>
#       <td>0.855505</td>
#     </tr>
#     <tr>
#       <td>12500</td>
#       <td>0.222500</td>
#       <td>0.477251</td>
#       <td>0.887615</td>
#     </tr>
#     <tr>
#       <td>13000</td>
#       <td>0.191500</td>
#       <td>0.449886</td>
#       <td>0.887615</td>
#     </tr>
#     <tr>
#       <td>13500</td>
#       <td>0.213100</td>
#       <td>0.444800</td>
#       <td>0.885321</td>
#     </tr>
#     <tr>
#       <td>14000</td>
#       <td>0.220400</td>
#       <td>0.409994</td>
#       <td>0.888761</td>
#     </tr>
#     <tr>
#       <td>14500</td>
#       <td>0.218500</td>
#       <td>0.406045</td>
#       <td>0.883028</td>
#     </tr>
#     <tr>
#       <td>15000</td>
#       <td>0.226000</td>
#       <td>0.398116</td>
#       <td>0.895642</td>
#     </tr>
#     <tr>
#       <td>15500</td>
#       <td>0.214000</td>
#       <td>0.450514</td>
#       <td>0.891055</td>
#     </tr>
#     <tr>
#       <td>16000</td>
#       <td>0.189400</td>
#       <td>0.482794</td>
#       <td>0.899083</td>
#     </tr>
#     <tr>
#       <td>16500</td>
#       <td>0.212100</td>
#       <td>0.564335</td>
#       <td>0.873853</td>
#     </tr>
#     <tr>
#       <td>17000</td>
#       <td>0.172400</td>
#       <td>0.496255</td>
#       <td>0.897936</td>
#     </tr>
#     <tr>
#       <td>17500</td>
#       <td>0.139600</td>
#       <td>0.472496</td>
#       <td>0.878440</td>
#     </tr>
#     <tr>
#       <td>18000</td>
#       <td>0.151400</td>
#       <td>0.501965</td>
#       <td>0.885321</td>
#     </tr>
#     <tr>
#       <td>18500</td>
#       <td>0.149200</td>
#       <td>0.507869</td>
#       <td>0.899083</td>
#     </tr>
#     <tr>
#       <td>19000</td>
#       <td>0.161400</td>
#       <td>0.500907</td>
#       <td>0.892202</td>
#     </tr>
#     <tr>
#       <td>19500</td>
#       <td>0.155200</td>
#       <td>0.409568</td>
#       <td>0.900229</td>
#     </tr>
#     <tr>
#       <td>20000</td>
#       <td>0.134900</td>
#       <td>0.475202</td>
#       <td>0.892202</td>
#     </tr>
#     <tr>
#       <td>20500</td>
#       <td>0.158000</td>
#       <td>0.495704</td>
#       <td>0.897936</td>
#     </tr>
#     <tr>
#       <td>21000</td>
#       <td>0.148400</td>
#       <td>0.437970</td>
#       <td>0.899083</td>
#     </tr>
#     <tr>
#       <td>21500</td>
#       <td>0.140100</td>
#       <td>0.546739</td>
#       <td>0.886468</td>
#     </tr>
#     <tr>
#       <td>22000</td>
#       <td>0.154400</td>
#       <td>0.388700</td>
#       <td>0.901376</td>
#     </tr>
#     <tr>
#       <td>22500</td>
#       <td>0.170700</td>
#       <td>0.472088</td>
#       <td>0.901376</td>
#     </tr>
#     <tr>
#       <td>23000</td>
#       <td>0.161000</td>
#       <td>0.497362</td>
#       <td>0.894495</td>
#     </tr>
#     <tr>
#       <td>23500</td>
#       <td>0.155500</td>
#       <td>0.427825</td>
#       <td>0.899083</td>
#     </tr>
#     <tr>
#       <td>24000</td>
#       <td>0.140000</td>
#       <td>0.478683</td>
#       <td>0.893349</td>
#     </tr>
#     <tr>
#       <td>24500</td>
#       <td>0.158300</td>
#       <td>0.527537</td>
#       <td>0.878440</td>
#     </tr>
#     <tr>
#       <td>25000</td>
#       <td>0.156900</td>
#       <td>0.506852</td>
#       <td>0.896789</td>
#     </tr>
#     <tr>
#       <td>25500</td>
#       <td>0.127600</td>
#       <td>0.546808</td>
#       <td>0.891055</td>
#     </tr>
#     <tr>
#       <td>26000</td>
#       <td>0.109100</td>
#       <td>0.509402</td>
#       <td>0.894495</td>
#     </tr>
#     <tr>
#       <td>26500</td>
#       <td>0.103200</td>
#       <td>0.585195</td>
#       <td>0.892202</td>
#     </tr>
#     <tr>
#       <td>27000</td>
#       <td>0.120600</td>
#       <td>0.420033</td>
#       <td>0.897936</td>
#     </tr>
#     <tr>
#       <td>27500</td>
#       <td>0.113300</td>
#       <td>0.603984</td>
#       <td>0.879587</td>
#     </tr>
#     <tr>
#       <td>28000</td>
#       <td>0.115900</td>
#       <td>0.500933</td>
#       <td>0.888761</td>
#     </tr>
#     <tr>
#       <td>28500</td>
#       <td>0.113500</td>
#       <td>0.567382</td>
#       <td>0.893349</td>
#     </tr>
#     <tr>
#       <td>29000</td>
#       <td>0.117900</td>
#       <td>0.504841</td>
#       <td>0.888761</td>
#     </tr>
#     <tr>
#       <td>29500</td>
#       <td>0.110500</td>
#       <td>0.631440</td>
#       <td>0.881881</td>
#     </tr>
#     <tr>
#       <td>30000</td>
#       <td>0.117300</td>
#       <td>0.553172</td>
#       <td>0.887615</td>
#     </tr>
#     <tr>
#       <td>30500</td>
#       <td>0.115700</td>
#       <td>0.480279</td>
#       <td>0.892202</td>
#     </tr>
#     <tr>
#       <td>31000</td>
#       <td>0.094900</td>
#       <td>0.577175</td>
#       <td>0.881881</td>
#     </tr>
#     <tr>
#       <td>31500</td>
#       <td>0.121700</td>
#       <td>0.532524</td>
#       <td>0.893349</td>
#     </tr>
#     <tr>
#       <td>32000</td>
#       <td>0.112100</td>
#       <td>0.470741</td>
#       <td>0.897936</td>
#     </tr>
#     <tr>
#       <td>32500</td>
#       <td>0.113400</td>
#       <td>0.529573</td>
#       <td>0.894495</td>
#     </tr>
#     <tr>
#       <td>33000</td>
#       <td>0.113000</td>
#       <td>0.520757</td>
#       <td>0.892202</td>
#     </tr>
#     <tr>
#       <td>33500</td>
#       <td>0.112800</td>
#       <td>0.479107</td>
#       <td>0.893349</td>
#     </tr>
#     <tr>
#       <td>34000</td>
#       <td>0.098800</td>
#       <td>0.578650</td>
#       <td>0.887615</td>
#     </tr>
#     <t
# The following columns in the evaluation set don't have a corresponding argument in `BertForSequenceClassification.forward` and have been ignored: sentence, idx. If sentence, idx are not expected by `BertForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 872
#   Batch size = 8
# Downloading builder script:   0%|          | 0.00/5.75k [00:00<?, ?B/s]
# Saving model checkpoint to ./results2/checkpoint-500
# Configuration saved in ./results2/checkpoint-500/config.json
# Model weights saved in ./results2/checkpoint-500/pytorch_model.bin
# tokenizer config file saved in ./results2/checkpoint-500/tokenizer_config.json
# Special tokens file saved in ./results2/checkpoint-500/special_tokens_map.json
# The following columns in the evaluation set don't have a corresponding argument in `BertForSequenceClassification.forward` and have been ignored: sentence, idx. If sentence, idx are not expected by `BertForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 872
#   Batch size = 8
# Saving model checkpoint to ./results2/checkpoint-1000
# Configuration saved in ./results2/checkpoint-1000/config.json
# Model weights saved in ./results2/checkpoint-1000/pytorch_model.bin
# tokenizer config file saved in ./results2/checkpoint-1000/tokenizer_config.json
# Special tokens file saved in ./results2/checkpoint-1000/special_tokens_map.json
# The following columns in the evaluation set don't have a corresponding argument in `BertForSequenceClassification.forward` and have been ignored: sentence, idx. If sentence, idx are not expected by `BertForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 872
#   Batch size = 8
# Saving model checkpoint to ./results2/checkpoint-1500
# Configuration saved in ./results2/checkpoint-1500/config.json
# Model weights saved in ./results2/checkpoint-1500/pytorch_model.bin
# tokenizer config file saved in ./results2/checkpoint-1500/tokenizer_config.json
# Special tokens file saved in ./results2/checkpoint-1500/special_tokens_map.json
# The following columns in the evaluation set don't have a corresponding argument in `BertForSequenceClassification.forward` and have been ignored: sentence, idx. If sentence, idx are not expected by `BertForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 872
#   Batch size = 8
# Saving model checkpoint to ./results2/checkpoint-2000
# Configuration saved in ./results2/checkpoint-2000/config.json
# Model weights saved in ./results2/checkpoint-2000/pytorch_model.bin
# tokenizer config file saved in ./results2/checkpoint-2000/tokenizer_config.json
# Special tokens file saved in ./results2/checkpoint-2000/special_tokens_map.json
# The following columns in the evaluation set don't have a corresponding argument in `BertForSequenceClassification.forward` and have been ignored: sentence, idx. If sentence, idx are not expected by `BertForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 872
#   Batch size = 8
# Saving model checkpoint to ./results2/checkpoint-2500
# Configuration saved in ./results2/checkpoint-2500/config.json
# Model weights saved in ./results2/checkpoint-2500/pytorch_model.bin
# tokenizer config file saved in ./results2/checkpoint-2500/tokenizer_config.json
# Special tokens file saved in ./results2/checkpoint-2500/special_tokens_map.json
# The following columns in the evaluation set don't have a corresponding argument in `BertForSequenceClassification.forward` and have been ignored: sentence, idx. If sentence, idx are not expected by `BertForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 872
#   Batch size = 8
# Saving model checkpoint to ./results2/checkpoint-3000
# Configuration saved in ./results2/checkpoint-3000/config.json
# Model weights saved in ./results2/checkpoint-3000/pytorch_model.bin
# tokenizer config file saved in ./results2/checkpoint-3000/tokenizer_config.json
# Special tokens file saved in ./results2/checkpoint-3000/special_tokens_map.json
# The following columns in the evaluation set don't have a corresponding argument in `BertForSequenceClassification.forward` and have been ignored: sentence, idx. If sentence, idx are not expected by `BertForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 872
#   Batch size = 8
# Saving model checkpoint to ./results2/checkpoint-3500
# Configuration saved in ./results2/checkpoint-3500/config.json
# Model weights saved in ./results2/checkpoint-3500/pytorch_model.bin
# tokenizer config file saved in ./results2/checkpoint-3500/tokenizer_config.json
# Special tokens file saved in ./results2/checkpoint-3500/special_tokens_map.json
# The following columns in the evaluation set don't have a corresponding argument in `BertForSequenceClassification.forward` and have been ignored: sentence, idx. If sentence, idx are not expected by `BertForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 872
#   Batch size = 8
# Saving model checkpoint to ./results2/checkpoint-4000
# Configuration saved in ./results2/checkpoint-4000/config.json
# Model weights saved in ./results2/checkpoint-4000/pytorch_model.bin
# tokenizer config file saved in ./results2/checkpoint-4000/tokenizer_config.json
# Special tokens file saved in ./results2/checkpoint-4000/special_tokens_map.json
# The following columns in the evaluation set don't have a corresponding argument in `BertForSequenceClassification.forward` and have been ignored: sentence, idx. If sentence, idx are not expected by `BertForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 872
#   Batch size = 8
# Saving model checkpoint to ./results2/checkpoint-4500
# Configuration saved in ./results2/checkpoint-4500/config.json
# Model weights saved in ./results2/checkpoint-4500/pytorch_model.bin
# tokenizer config file saved in ./results2/checkpoint-4500/tokenizer_config.json
# Special tokens file saved in ./results2/checkpoint-4500/special_tokens_map.json
# The following columns in the evaluation set don't have a corresponding argument in `BertForSequenceClassification.forward` and have been ignored: sentence, idx. If sentence, idx are not expected by `BertForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 872
#   Batch size = 8
# Saving model checkpoint to ./results2/checkpoint-5000
# Configuration saved in ./results2/checkpoint-5000/config.json
# Model weights saved in ./results2/checkpoint-5000/pytorch_model.bin
# tokenizer config file saved in ./results2/checkpoint-5000/tokenizer_config.json
# Special tokens file saved in ./results2/checkpoint-5000/special_tokens_map.json
# The following columns in the evaluation set don't have a corresponding argument in `BertForSequenceClassification.forward` and have been ignored: sentence, idx. If sentence, idx are not expected by `BertForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 872
#   Batch size = 8
# Saving model checkpoint to ./results2/checkpoint-5500
# Configuration saved in ./results2/checkpoint-5500/config.json
# Model weights saved in ./results2/checkpoint-5500/pytorch_model.bin
# tokenizer config file saved in ./results2/checkpoint-5500/tokenizer_config.json
# Special tokens file saved in ./results2/checkpoint-5500/special_tokens_map.json
# The following columns in the evaluation set don't have a corresponding argument in `BertForSequenceClassification.forward` and have been ignored: sentence, idx. If sentence, idx are not expected by `BertForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 872
#   Batch size = 8
# Saving model checkpoint to ./results2/checkpoint-6000
# Configuration saved in ./results2/checkpoint-6000/config.json
# Model weights saved in ./results2/checkpoint-6000/pytorch_model.bin
# tokenizer config file saved in ./results2/checkpoint-6000/tokenizer_config.json
# Special tokens file saved in ./results2/checkpoint-6000/special_tokens_map.json
# The following columns in the evaluation set don't have a corresponding argument in `BertForSequenceClassification.forward` and have been ignored: sentence, idx. If sentence, idx are not expected by `BertForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 872
#   Batch size = 8
# Saving model checkpoint to ./results2/checkpoint-6500
# Configuration saved in ./results2/checkpoint-6500/config.json
# Model weights saved in ./results2/checkpoint-6500/pytorch_model.bin
# tokenizer config file saved in ./results2/checkpoint-6500/tokenizer_config.json
# Special tokens file saved in ./results2/checkpoint-6500/special_tokens_map.json
# The following columns in the evaluation set don't have a corresponding argument in `BertForSequenceClassification.forward` and have been ignored: sentence, idx. If sentence, idx are not expected by `BertForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 872
#   Batch size = 8
# Saving model checkpoint to ./results2/checkpoint-7000
# Configuration saved in ./results2/checkpoint-7000/config.json
# Model weights saved in ./results2/checkpoint-7000/pytorch_model.bin
# tokenizer config file saved in ./results2/checkpoint-7000/tokenizer_config.json
# Special tokens file saved in ./results2/checkpoint-7000/special_tokens_map.json
# The following columns in the evaluation set don't have a corresponding argument in `BertForSequenceClassification.forward` and have been ignored: sentence, idx. If sentence, idx are not expected by `BertForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 872
#   Batch size = 8
# Saving model checkpoint to ./results2/checkpoint-7500
# Configuration saved in ./results2/checkpoint-7500/config.json
# Model weights saved in ./results2/checkpoint-7500/pytorch_model.bin
# tokenizer config file saved in ./results2/checkpoint-7500/tokenizer_config.json
# Special tokens file saved in ./results2/checkpoint-7500/special_tokens_map.json
# The following columns in the evaluation set don't have a corresponding argument in `BertForSequenceClassification.forward` and have been ignored: sentence, idx. If sentence, idx are not expected by `BertForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 872
#   Batch size = 8
# Saving model checkpoint to ./results2/checkpoint-8000
# Configuration saved in ./results2/checkpoint-8000/config.json
# Model weights saved in ./results2/checkpoint-8000/pytorch_model.bin
# tokenizer config file saved in ./results2/checkpoint-8000/tokenizer_config.json
# Special tokens file saved in ./results2/checkpoint-8000/special_tokens_map.json
# The following columns in the evaluation set don't have a corresponding argument in `BertForSequenceClassification.forward` and have been ignored: sentence, idx. If sentence, idx are not expected by `BertForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 872
#   Batch size = 8
# Saving model checkpoint to ./results2/checkpoint-8500
# Configuration saved in ./results2/checkpoint-8500/config.json
# Model weights saved in ./results2/checkpoint-8500/pytorch_model.bin
# tokenizer config file saved in ./results2/checkpoint-8500/tokenizer_config.json
# Special tokens file saved in ./results2/checkpoint-8500/special_tokens_map.json
# The following columns in the evaluation set don't have a corresponding argument in `BertForSequenceClassification.forward` and have been ignored: sentence, idx. If sentence, idx are not expected by `BertForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 872
#   Batch size = 8
# Saving model checkpoint to ./results2/checkpoint-9000
# Configuration saved in ./results2/checkpoint-9000/config.json
# Model weights saved in ./results2/checkpoint-9000/pytorch_model.bin
# tokenizer config file saved in ./results2/checkpoint-9000/tokenizer_config.json
# Special tokens file saved in ./results2/checkpoint-9000/special_tokens_map.json
# The following columns in the evaluation set don't have a corresponding argument in `BertForSequenceClassification.forward` and have been ignored: sentence, idx. If sentence, idx are not expected by `BertForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 872
#   Batch size = 8
# Saving model checkpoint to ./results2/checkpoint-9500
# Configuration saved in ./results2/checkpoint-9500/config.json
# Model weights saved in ./results2/checkpoint-9500/pytorch_model.bin
# tokenizer config file saved in ./results2/checkpoint-9500/tokenizer_config.json
# Special tokens file saved in ./results2/checkpoint-9500/special_tokens_map.json
# The following columns in the evaluation set don't have a corresponding argument in `BertForSequenceClassification.forward` and have been ignored: sentence, idx. If sentence, idx are not expected by `BertForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 872
#   Batch size = 8
# Saving model checkpoint to ./results2/checkpoint-10000
# Configuration saved in ./results2/checkpoint-10000/config.json
# Model weights saved in ./results2/checkpoint-10000/pytorch_model.bin
# tokenizer config file saved in ./results2/checkpoint-10000/tokenizer_config.json
# Special tokens file saved in ./results2/checkpoint-10000/special_tokens_map.json
# The following columns in the evaluation set don't have a corresponding argument in `BertForSequenceClassification.forward` and have been ignored: sentence, idx. If sentence, idx are not expected by `BertForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 872
#   Batch size = 8
# Saving model checkpoint to ./results2/checkpoint-10500
# Configuration saved in ./results2/checkpoint-10500/config.json
# Model weights saved in ./results2/checkpoint-10500/pytorch_model.bin
# tokenizer config file saved in ./results2/checkpoint-10500/tokenizer_config.json
# Special tokens file saved in ./results2/checkpoint-10500/special_tokens_map.json
# The following columns in the evaluation set don't have a corresponding argument in `BertForSequenceClassification.forward` and have been ignored: sentence, idx. If sentence, idx are not expected by `BertForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 872
#   Batch size = 8
# Saving model checkpoint to ./results2/checkpoint-11000
# Configuration saved in ./results2/checkpoint-11000/config.json
# Model weights saved in ./results2/checkpoint-11000/pytorch_model.bin
# tokenizer config file saved in ./results2/checkpoint-11000/tokenizer_config.json
# Special tokens file saved in ./results2/checkpoint-11000/special_tokens_map.json
# The following columns in the evaluation set don't have a corresponding argument in `BertForSequenceClassification.forward` and have been ignored: sentence, idx. If sentence, idx are not expected by `BertForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 872
#   Batch size = 8
# Saving model checkpoint to ./results2/checkpoint-11500
# Configuration saved in ./results2/checkpoint-11500/config.json
# Model weights saved in ./results2/checkpoint-11500/pytorch_model.bin
# tokenizer config file saved in ./results2/checkpoint-11500/tokenizer_config.json
# Special tokens file saved in ./results2/checkpoint-11500/special_tokens_map.json
# The following columns in the evaluation set don't have a corresponding argument in `BertForSequenceClassification.forward` and have been ignored: sentence, idx. If sentence, idx are not expected by `BertForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 872
#   Batch size = 8
# Saving model checkpoint to ./results2/checkpoint-12000
# Configuration saved in ./results2/checkpoint-12000/config.json
# Model weights saved in ./results2/checkpoint-12000/pytorch_model.bin
# tokenizer config file saved in ./results2/checkpoint-12000/tokenizer_config.json
# Special tokens file saved in ./results2/checkpoint-12000/special_tokens_map.json
# The following columns in the evaluation set don't have a corresponding argument in `BertForSequenceClassification.forward` and have been ignored: sentence, idx. If sentence, idx are not expected by `BertForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 872
#   Batch size = 8
# Saving model checkpoint to ./results2/checkpoint-12500
# Configuration saved in ./results2/checkpoint-12500/config.json
# Model weights saved in ./results2/checkpoint-12500/pytorch_model.bin
# tokenizer config file saved in ./results2/checkpoint-12500/tokenizer_config.json
# Special tokens file saved in ./results2/checkpoint-12500/special_tokens_map.json
# The following columns in the evaluation set don't have a corresponding argument in `BertForSequenceClassification.forward` and have been ignored: sentence, idx. If sentence, idx are not expected by `BertForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 872
#   Batch size = 8
# Saving model checkpoint to ./results2/checkpoint-13000
# Configuration saved in ./results2/checkpoint-13000/config.json
# Model weights saved in ./results2/checkpoint-13000/pytorch_model.bin
# tokenizer config file saved in ./results2/checkpoint-13000/tokenizer_config.json
# Special tokens file saved in ./results2/checkpoint-13000/special_tokens_map.json
# The following columns in the evaluation set don't have a corresponding argument in `BertForSequenceClassification.forward` and have been ignored: sentence, idx. If sentence, idx are not expected by `BertForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 872
#   Batch size = 8
# Saving model checkpoint to ./results2/checkpoint-13500
# Configuration saved in ./results2/checkpoint-13500/config.json
# Model weights saved in ./results2/checkpoint-13500/pytorch_model.bin
# tokenizer config file saved in ./results2/checkpoint-13500/tokenizer_config.json
# Special tokens file saved in ./results2/checkpoint-13500/special_tokens_map.json
# The following columns in the evaluation set don't have a corresponding argument in `BertForSequenceClassification.forward` and have been ignored: sentence, idx. If sentence, idx are not expected by `BertForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 872
#   Batch size = 8
# Saving model checkpoint to ./results2/checkpoint-14000
# Configuration saved in ./results2/checkpoint-14000/config.json
# Model weights saved in ./results2/checkpoint-14000/pytorch_model.bin
# tokenizer config file saved in ./results2/checkpoint-14000/tokenizer_config.json
# Special tokens file saved in ./results2/checkpoint-14000/special_tokens_map.json
# The following columns in the evaluation set don't have a corresponding argument in `BertForSequenceClassification.forward` and have been ignored: sentence, idx. If sentence, idx are not expected by `BertForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 872
#   Batch size = 8
# Saving model checkpoint to ./results2/checkpoint-14500
# Configuration saved in ./results2/checkpoint-14500/config.json
# Model weights saved in ./results2/checkpoint-14500/pytorch_model.bin
# tokenizer config file saved in ./results2/checkpoint-14500/tokenizer_config.json
# Special tokens file saved in ./results2/checkpoint-14500/special_tokens_map.json
# The following columns in the evaluation set don't have a corresponding argument in `BertForSequenceClassification.forward` and have been ignored: sentence, idx. If sentence, idx are not expected by `BertForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 872
#   Batch size = 8
# Saving model checkpoint to ./results2/checkpoint-15000
# Configuration saved in ./results2/checkpoint-15000/config.json
# Model weights saved in ./results2/checkpoint-15000/pytorch_model.bin
# tokenizer config file saved in ./results2/checkpoint-15000/tokenizer_config.json
# Special tokens file saved in ./results2/checkpoint-15000/special_tokens_map.json
# The following columns in the evaluation set don't have a corresponding argument in `BertForSequenceClassification.forward` and have been ignored: sentence, idx. If sentence, idx are not expected by `BertForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 872
#   Batch size = 8
# Saving model checkpoint to ./results2/checkpoint-15500
# Configuration saved in ./results2/checkpoint-15500/config.json
# Model weights saved in ./results2/checkpoint-15500/pytorch_model.bin
# tokenizer config file saved in ./results2/checkpoint-15500/tokenizer_config.json
# Special tokens file saved in ./results2/checkpoint-15500/special_tokens_map.json
# The following columns in the evaluation set don't have a corresponding argument in `BertForSequenceClassification.forward` and have been ignored: sentence, idx. If sentence, idx are not expected by `BertForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 872
#   Batch size = 8
# Saving model checkpoint to ./results2/checkpoint-16000
# Configuration saved in ./results2/checkpoint-16000/config.json
# Model weights saved in ./results2/checkpoint-16000/pytorch_model.bin
# tokenizer config file saved in ./results2/checkpoint-16000/tokenizer_config.json
# Special tokens file saved in ./results2/checkpoint-16000/special_tokens_map.json
# The following columns in the evaluation set don't have a corresponding argument in `BertForSequenceClassification.forward` and have been ignored: sentence, idx. If sentence, idx are not expected by `BertForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 872
#   Batch size = 8
# Saving model checkpoint to ./results2/checkpoint-16500
# Configuration saved in ./results2/checkpoint-16500/config.json
# Model weights saved in ./results2/checkpoint-16500/pytorch_model.bin
# tokenizer config file saved in ./results2/checkpoint-16500/tokenizer_config.json
# Special tokens file saved in ./results2/checkpoint-16500/special_tokens_map.json
# The following columns in the evaluation set don't have a corresponding argument in `BertForSequenceClassification.forward` and have been ignored: sentence, idx. If sentence, idx are not expected by `BertForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 872
#   Batch size = 8
# Saving model checkpoint to ./results2/checkpoint-17000
# Configuration saved in ./results2/checkpoint-17000/config.json
# Model weights saved in ./results2/checkpoint-17000/pytorch_model.bin
# tokenizer config file saved in ./results2/checkpoint-17000/tokenizer_config.json
# Special tokens file saved in ./results2/checkpoint-17000/special_tokens_map.json
# The following columns in the evaluation set don't have a corresponding argument in `BertForSequenceClassification.forward` and have been ignored: sentence, idx. If sentence, idx are not expected by `BertForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 872
#   Batch size = 8
# Saving model checkpoint to ./results2/checkpoint-17500
# Configuration saved in ./results2/checkpoint-17500/config.json
# Model weights saved in ./results2/checkpoint-17500/pytorch_model.bin
# tokenizer config file saved in ./results2/checkpoint-17500/tokenizer_config.json
# Special tokens file saved in ./results2/checkpoint-17500/special_tokens_map.json
# The following columns in the evaluation set don't have a corresponding argument in `BertForSequenceClassification.forward` and have been ignored: sentence, idx. If sentence, idx are not expected by `BertForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 872
#   Batch size = 8
# Saving model checkpoint to ./results2/checkpoint-18000
# Configuration saved in ./results2/checkpoint-18000/config.json
# Model weights saved in ./results2/checkpoint-18000/pytorch_model.bin
# tokenizer config file saved in ./results2/checkpoint-18000/tokenizer_config.json
# Special tokens file saved in ./results2/checkpoint-18000/special_tokens_map.json
# The following columns in the evaluation set don't have a corresponding argument in `BertForSequenceClassification.forward` and have been ignored: sentence, idx. If sentence, idx are not expected by `BertForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 872
#   Batch size = 8
# Saving model checkpoint to ./results2/checkpoint-18500
# Configuration saved in ./results2/checkpoint-18500/config.json
# Model weights saved in ./results2/checkpoint-18500/pytorch_model.bin
# tokenizer config file saved in ./results2/checkpoint-18500/tokenizer_config.json
# Special tokens file saved in ./results2/checkpoint-18500/special_tokens_map.json
# The following columns in the evaluation set don't have a corresponding argument in `BertForSequenceClassification.forward` and have been ignored: sentence, idx. If sentence, idx are not expected by `BertForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 872
#   Batch size = 8
# Saving model checkpoint to ./results2/checkpoint-19000
# Configuration saved in ./results2/checkpoint-19000/config.json
# Model weights saved in ./results2/checkpoint-19000/pytorch_model.bin
# tokenizer config file saved in ./results2/checkpoint-19000/tokenizer_config.json
# Special tokens file saved in ./results2/checkpoint-19000/special_tokens_map.json
# The following columns in the evaluation set don't have a corresponding argument in `BertForSequenceClassification.forward` and have been ignored: sentence, idx. If sentence, idx are not expected by `BertForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 872
#   Batch size = 8
# Saving model checkpoint to ./results2/checkpoint-19500
# Configuration saved in ./results2/checkpoint-19500/config.json
# Model weights saved in ./results2/checkpoint-19500/pytorch_model.bin
# tokenizer config file saved in ./results2/checkpoint-19500/tokenizer_config.json
# Special tokens file saved in ./results2/checkpoint-19500/special_tokens_map.json
# The following columns in the evaluation set don't have a corresponding argument in `BertForSequenceClassification.forward` and have been ignored: sentence, idx. If sentence, idx are not expected by `BertForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 872
#   Batch size = 8
# Saving model checkpoint to ./results2/checkpoint-20000
# Configuration saved in ./results2/checkpoint-20000/config.json
# Model weights saved in ./results2/checkpoint-20000/pytorch_model.bin
# tokenizer config file saved in ./results2/checkpoint-20000/tokenizer_config.json
# Special tokens file saved in ./results2/checkpoint-20000/special_tokens_map.json
# The following columns in the evaluation set don't have a corresponding argument in `BertForSequenceClassification.forward` and have been ignored: sentence, idx. If sentence, idx are not expected by `BertForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 872
#   Batch size = 8
# Saving model checkpoint to ./results2/checkpoint-20500
# Configuration saved in ./results2/checkpoint-20500/config.json
# Model weights saved in ./results2/checkpoint-20500/pytorch_model.bin
# tokenizer config file saved in ./results2/checkpoint-20500/tokenizer_config.json
# Special tokens file saved in ./results2/checkpoint-20500/special_tokens_map.json
# The following columns in the evaluation set don't have a corresponding argument in `BertForSequenceClassification.forward` and have been ignored: sentence, idx. If sentence, idx are not expected by `BertForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 872
#   Batch size = 8
# Saving model checkpoint to ./results2/checkpoint-21000
# Configuration saved in ./results2/checkpoint-21000/config.json
# Model weights saved in ./results2/checkpoint-21000/pytorch_model.bin
# tokenizer config file saved in ./results2/checkpoint-21000/tokenizer_config.json
# Special tokens file saved in ./results2/checkpoint-21000/special_tokens_map.json
# The following columns in the evaluation set don't have a corresponding argument in `BertForSequenceClassification.forward` and have been ignored: sentence, idx. If sentence, idx are not expected by `BertForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 872
#   Batch size = 8
# Saving model checkpoint to ./results2/checkpoint-21500
# Configuration saved in ./results2/checkpoint-21500/config.json
# Model weights saved in ./results2/checkpoint-21500/pytorch_model.bin
# tokenizer config file saved in ./results2/checkpoint-21500/tokenizer_config.json
# Special tokens file saved in ./results2/checkpoint-21500/special_tokens_map.json
# The following columns in the evaluation set don't have a corresponding argument in `BertForSequenceClassification.forward` and have been ignored: sentence, idx. If sentence, idx are not expected by `BertForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 872
#   Batch size = 8
# Saving model checkpoint to ./results2/checkpoint-22000
# Configuration saved in ./results2/checkpoint-22000/config.json
# Model weights saved in ./results2/checkpoint-22000/pytorch_model.bin
# tokenizer config file saved in ./results2/checkpoint-22000/tokenizer_config.json
# Special tokens file saved in ./results2/checkpoint-22000/special_tokens_map.json
# The following columns in the evaluation set don't have a corresponding argument in `BertForSequenceClassification.forward` and have been ignored: sentence, idx. If sentence, idx are not expected by `BertForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 872
#   Batch size = 8
# Saving model checkpoint to ./results2/checkpoint-22500
# Configuration saved in ./results2/checkpoint-22500/config.json
# Model weights saved in ./results2/checkpoint-22500/pytorch_model.bin
# tokenizer config file saved in ./results2/checkpoint-22500/tokenizer_config.json
# Special tokens file saved in ./results2/checkpoint-22500/special_tokens_map.json
# The following columns in the evaluation set don't have a corresponding argument in `BertForSequenceClassification.forward` and have been ignored: sentence, idx. If sentence, idx are not expected by `BertForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 872
#   Batch size = 8
# Saving model checkpoint to ./results2/checkpoint-23000
# Configuration saved in ./results2/checkpoint-23000/config.json
# Model weights saved in ./results2/checkpoint-23000/pytorch_model.bin
# tokenizer config file saved in ./results2/checkpoint-23000/tokenizer_config.json
# Special tokens file saved in ./results2/checkpoint-23000/special_tokens_map.json
# The following columns in the evaluation set don't have a corresponding argument in `BertForSequenceClassification.forward` and have been ignored: sentence, idx. If sentence, idx are not expected by `BertForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 872
#   Batch size = 8
# Saving model checkpoint to ./results2/checkpoint-23500
# Configuration saved in ./results2/checkpoint-23500/config.json
# Model weights saved in ./results2/checkpoint-23500/pytorch_model.bin
# tokenizer config file saved in ./results2/checkpoint-23500/tokenizer_config.json
# Special tokens file saved in ./results2/checkpoint-23500/special_tokens_map.json
# The following columns in the evaluation set don't have a corresponding argument in `BertForSequenceClassification.forward` and have been ignored: sentence, idx. If sentence, idx are not expected by `BertForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 872
#   Batch size = 8
# Saving model checkpoint to ./results2/checkpoint-24000
# Configuration saved in ./results2/checkpoint-24000/config.json
# Model weights saved in ./results2/checkpoint-24000/pytorch_model.bin
# tokenizer config file saved in ./results2/checkpoint-24000/tokenizer_config.json
# Special tokens file saved in ./results2/checkpoint-24000/special_tokens_map.json
# The following columns in the evaluation set don't have a corresponding argument in `BertForSequenceClassification.forward` and have been ignored: sentence, idx. If sentence, idx are not expected by `BertForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 872
#   Batch size = 8
# Saving model checkpoint to ./results2/checkpoint-24500
# Configuration saved in ./results2/checkpoint-24500/config.json
# Model weights saved in ./results2/checkpoint-24500/pytorch_model.bin
# tokenizer config file saved in ./results2/checkpoint-24500/tokenizer_config.json
# Special tokens file saved in ./results2/checkpoint-24500/special_tokens_map.json
# The following columns in the evaluation set don't have a corresponding argument in `BertForSequenceClassification.forward` and have been ignored: sentence, idx. If sentence, idx are not expected by `BertForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 872
#   Batch size = 8
# Saving model checkpoint to ./results2/checkpoint-25000
# Configuration saved in ./results2/checkpoint-25000/config.json
# Model weights saved in ./results2/checkpoint-25000/pytorch_model.bin
# tokenizer config file saved in ./results2/checkpoint-25000/tokenizer_config.json
# Special tokens file saved in ./results2/checkpoint-25000/special_tokens_map.json
# The following columns in the evaluation set don't have a corresponding argument in `BertForSequenceClassification.forward` and have been ignored: sentence, idx. If sentence, idx are not expected by `BertForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 872
#   Batch size = 8
# Saving model checkpoint to ./results2/checkpoint-25500
# Configuration saved in ./results2/checkpoint-25500/config.json
# Model weights saved in ./results2/checkpoint-25500/pytorch_model.bin
# tokenizer config file saved in ./results2/checkpoint-25500/tokenizer_config.json
# Special tokens file saved in ./results2/checkpoint-25500/special_tokens_map.json
# The following columns in the evaluation set don't have a corresponding argument in `BertForSequenceClassification.forward` and have been ignored: sentence, idx. If sentence, idx are not expected by `BertForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 872
#   Batch size = 8
# Saving model checkpoint to ./results2/checkpoint-26000
# Configuration saved in ./results2/checkpoint-26000/config.json
# Model weights saved in ./results2/checkpoint-26000/pytorch_model.bin
# tokenizer config file saved in ./results2/checkpoint-26000/tokenizer_config.json
# Special tokens file saved in ./results2/checkpoint-26000/special_tokens_map.json
# The following columns in the evaluation set don't have a corresponding argument in `BertForSequenceClassification.forward` and have been ignored: sentence, idx. If sentence, idx are not expected by `BertForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 872
#   Batch size = 8
# Saving model checkpoint to ./results2/checkpoint-26500
# Configuration saved in ./results2/checkpoint-26500/config.json
# Model weights saved in ./results2/checkpoint-26500/pytorch_model.bin
# tokenizer config file saved in ./results2/checkpoint-26500/tokenizer_config.json
# Special tokens file saved in ./results2/checkpoint-26500/special_tokens_map.json
# The following columns in the evaluation set don't have a corresponding argument in `BertForSequenceClassification.forward` and have been ignored: sentence, idx. If sentence, idx are not expected by `BertForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 872
#   Batch size = 8
# Saving model checkpoint to ./results2/checkpoint-27000
# Configuration saved in ./results2/checkpoint-27000/config.json
# Model weights saved in ./results2/checkpoint-27000/pytorch_model.bin
# tokenizer config file saved in ./results2/checkpoint-27000/tokenizer_config.json
# Special tokens file saved in ./results2/checkpoint-27000/special_tokens_map.json
# The following columns in the evaluation set don't have a corresponding argument in `BertForSequenceClassification.forward` and have been ignored: sentence, idx. If sentence, idx are not expected by `BertForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 872
#   Batch size = 8
# Saving model checkpoint to ./results2/checkpoint-27500
# Configuration saved in ./results2/checkpoint-27500/config.json
# Model weights saved in ./results2/checkpoint-27500/pytorch_model.bin
# tokenizer config file saved in ./results2/checkpoint-27500/tokenizer_config.json
# Special tokens file saved in ./results2/checkpoint-27500/special_tokens_map.json
# The following columns in the evaluation set don't have a corresponding argument in `BertForSequenceClassification.forward` and have been ignored: sentence, idx. If sentence, idx are not expected by `BertForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 872
#   Batch size = 8
# Saving model checkpoint to ./results2/checkpoint-28000
# Configuration saved in ./results2/checkpoint-28000/config.json
# Model weights saved in ./results2/checkpoint-28000/pytorch_model.bin
# tokenizer config file saved in ./results2/checkpoint-28000/tokenizer_config.json
# Special tokens file saved in ./results2/checkpoint-28000/special_tokens_map.json
# ...
#   Num examples = 872
#   Batch size = 8
# Saving model checkpoint to ./results2/checkpoint-31000
# Configuration saved in ./results2/checkpoint-31000/config.json
# Model weights saved in ./results2/checkpoint-31000/pytorch_model.bin
# tokenizer config file saved in ./results2/checkpoint-31000/tokenizer_config.json
# Special tokens file saved in ./results2/checkpoint-31000/special_tokens_map.json
# The following columns in the evaluation set don't have a corresponding argument in `BertForSequenceClassification.forward` and have been ignored: sentence, idx. If sentence, idx are not expected by `BertForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 872
#   Batch size = 8
# Saving model checkpoint to ./results2/checkpoint-31500
# Configuration saved in ./results2/checkpoint-31500/config.json
# Model weights saved in ./results2/checkpoint-31500/pytorch_model.bin
# tokenizer config file saved in ./results2/checkpoint-31500/tokenizer_config.json
# Special tokens file saved in ./results2/checkpoint-31500/special_tokens_map.json
# The following columns in the evaluation set don't have a corresponding argument in `BertForSequenceClassification.forward` and have been ignored: sentence, idx. If sentence, idx are not expected by `BertForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 872
#   Batch size = 8
# Saving model checkpoint to ./results2/checkpoint-32000
# Configuration saved in ./results2/checkpoint-32000/config.json
# Model weights saved in ./results2/checkpoint-32000/pytorch_model.bin
# tokenizer config file saved in ./results2/checkpoint-32000/tokenizer_config.json
# Special tokens file saved in ./results2/checkpoint-32000/special_tokens_map.json
# The following columns in the evaluation set don't have a corresponding argument in `BertForSequenceClassification.forward` and have been ignored: sentence, idx. If sentence, idx are not expected by `BertForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 872
#   Batch size = 8
# Saving model checkpoint to ./results2/checkpoint-32500
# Configuration saved in ./results2/checkpoint-32500/config.json
# Model weights saved in ./results2/checkpoint-32500/pytorch_model.bin
# tokenizer config file saved in ./results2/checkpoint-32500/tokenizer_config.json
# Special tokens file saved in ./results2/checkpoint-32500/special_tokens_map.json
# The following columns in the evaluation set don't have a corresponding argument in `BertForSequenceClassification.forward` and have been ignored: sentence, idx. If sentence, idx are not expected by `BertForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 872
#   Batch size = 8
# Saving model checkpoint to ./results2/checkpoint-33000
# Configuration saved in ./results2/checkpoint-33000/config.json
# Model weights saved in ./results2/checkpoint-33000/pytorch_model.bin
# tokenizer config file saved in ./results2/checkpoint-33000/tokenizer_config.json
# Special tokens file saved in ./results2/checkpoint-33000/special_tokens_map.json
# The following columns in the evaluation set don't have a corresponding argument in `BertForSequenceClassification.forward` and have been ignored: sentence, idx. If sentence, idx are not expected by `BertForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 872
#   Batch size = 8
# Saving model checkpoint to ./results2/checkpoint-33500
# Configuration saved in ./results2/checkpoint-33500/config.json
# Model weights saved in ./results2/checkpoint-33500/pytorch_model.bin
# tokenizer config file saved in ./results2/checkpoint-33500/tokenizer_config.json
# Special tokens file saved in ./results2/checkpoint-33500/special_tokens_map.json
# The following columns in the evaluation set don't have a corresponding argument in `BertForSequenceClassification.forward` and have been ignored: sentence, idx. If sentence, idx are not expected by `BertForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 872
#   Batch size = 8
# Saving model checkpoint to ./results2/checkpoint-34000
# Configuration saved in ./results2/checkpoint-34000/config.json
# Model weights saved in ./results2/checkpoint-34000/pytorch_model.bin
# tokenizer config file saved in ./results2/checkpoint-34000/tokenizer_config.json
# Special tokens file saved in ./results2/checkpoint-34000/special_tokens_map.json
# The following columns in the evaluation set don't have a corresponding argument in `BertForSequenceClassification.forward` and have been ignored: sentence, idx. If sentence, idx are not expected by `BertForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 872
#   Batch size = 8
# Saving model checkpoint to ./results2/checkpoint-34500
# Configuration saved in ./results2/checkpoint-34500/config.json
# Model weights saved in ./results2/checkpoint-34500/pytorch_model.bin
# tokenizer config file saved in ./results2/checkpoint-34500/tokenizer_config.json
# Special tokens file saved in ./results2/checkpoint-34500/special_tokens_map.json
# The following columns in the evaluation set don't have a corresponding argument in `BertForSequenceClassification.forward` and have been ignored: sentence, idx. If sentence, idx are not expected by `BertForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 872
#   Batch size = 8
# Saving model checkpoint to ./results2/checkpoint-35000
# Configuration saved in ./results2/checkpoint-35000/config.json
# Model weights saved in ./results2/checkpoint-35000/pytorch_model.bin
# tokenizer config file saved in ./results2/checkpoint-35000/tokenizer_config.json
# Special tokens file saved in ./results2/checkpoint-35000/special_tokens_map.json
# The following columns in the evaluation set don't have a corresponding argument in `BertForSequenceClassification.forward` and have been ignored: sentence, idx. If sentence, idx are not expected by `BertForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 872
#   Batch size = 8
# Saving model checkpoint to ./results2/checkpoint-35500
# Configuration saved in ./results2/checkpoint-35500/config.json
# Model weights saved in ./results2/checkpoint-35500/pytorch_model.bin
# tokenizer config file saved in ./results2/checkpoint-35500/tokenizer_config.json
# Special tokens file saved in ./results2/checkpoint-35500/special_tokens_map.json
# The following columns in the evaluation set don't have a corresponding argument in `BertForSequenceClassification.forward` and have been ignored: sentence, idx. If sentence, idx are not expected by `BertForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 872
#   Batch size = 8
# Saving model checkpoint to ./results2/checkpoint-36000
# Configuration saved in ./results2/checkpoint-36000/config.json
# Model weights saved in ./results2/checkpoint-36000/pytorch_model.bin
# tokenizer config file saved in ./results2/checkpoint-36000/tokenizer_config.json
# Special tokens file saved in ./results2/checkpoint-36000/special_tokens_map.json
# The following columns in the evaluation set don't have a corresponding argument in `BertForSequenceClassification.forward` and have been ignored: sentence, idx. If sentence, idx are not expected by `BertForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 872
#   Batch size = 8
# Saving model checkpoint to ./results2/checkpoint-36500
# Configuration saved in ./results2/checkpoint-36500/config.json
# Model weights saved in ./results2/checkpoint-36500/pytorch_model.bin
# tokenizer config file saved in ./results2/checkpoint-36500/tokenizer_config.json
# Special tokens file saved in ./results2/checkpoint-36500/special_tokens_map.json
# The following columns in the evaluation set don't have a corresponding argument in `BertForSequenceClassification.forward` and have been ignored: sentence, idx. If sentence, idx are not expected by `BertForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 872
#   Batch size = 8
# Saving model checkpoint to ./results2/checkpoint-37000
# Configuration saved in ./results2/checkpoint-37000/config.json
# Model weights saved in ./results2/checkpoint-37000/pytorch_model.bin
# tokenizer config file saved in ./results2/checkpoint-37000/tokenizer_config.json
# Special tokens file saved in ./results2/checkpoint-37000/special_tokens_map.json
# The following columns in the evaluation set don't have a corresponding argument in `BertForSequenceClassification.forward` and have been ignored: sentence, idx. If sentence, idx are not expected by `BertForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 872
#   Batch size = 8
# Saving model checkpoint to ./results2/checkpoint-37500
# Configuration saved in ./results2/checkpoint-37500/config.json
# Model weights saved in ./results2/checkpoint-37500/pytorch_model.bin
# tokenizer config file saved in ./results2/checkpoint-37500/tokenizer_config.json
# Special tokens file saved in ./results2/checkpoint-37500/special_tokens_map.json
# The following columns in the evaluation set don't have a corresponding argument in `BertForSequenceClassification.forward` and have been ignored: sentence, idx. If sentence, idx are not expected by `BertForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 872
#   Batch size = 8
# Saving model checkpoint to ./results2/checkpoint-38000
# Configuration saved in ./results2/checkpoint-38000/config.json
# Model weights saved in ./results2/checkpoint-38000/pytorch_model.bin
# tokenizer config file saved in ./results2/checkpoint-38000/tokenizer_config.json
# Special tokens file saved in ./results2/checkpoint-38000/special_tokens_map.json
# The following columns in the evaluation set don't have a corresponding argument in `BertForSequenceClassification.forward` and have been ignored: sentence, idx. If sentence, idx are not expected by `BertForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 872
#   Batch size = 8
# Saving model checkpoint to ./results2/checkpoint-38500
# Configuration saved in ./results2/checkpoint-38500/config.json
# Model weights saved in ./results2/checkpoint-38500/pytorch_model.bin
# tokenizer config file saved in ./results2/checkpoint-38500/tokenizer_config.json
# Special tokens file saved in ./results2/checkpoint-38500/special_tokens_map.json
# The following columns in the evaluation set don't have a corresponding argument in `BertForSequenceClassification.forward` and have been ignored: sentence, idx. If sentence, idx are not expected by `BertForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 872
#   Batch size = 8
# Saving model checkpoint to ./results2/checkpoint-39000
# Configuration saved in ./results2/checkpoint-39000/config.json
# Model weights saved in ./results2/checkpoint-39000/pytorch_model.bin
# tokenizer config file saved in ./results2/checkpoint-39000/tokenizer_config.json
# Special tokens file saved in ./results2/checkpoint-39000/special_tokens_map.json
# The following columns in the evaluation set don't have a corresponding argument in `BertForSequenceClassification.forward` and have been ignored: sentence, idx. If sentence, idx are not expected by `BertForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 872
#   Batch size = 8
# Saving model checkpoint to ./results2/checkpoint-39500
# Configuration saved in ./results2/checkpoint-39500/config.json
# Model weights saved in ./results2/checkpoint-39500/pytorch_model.bin
# tokenizer config file saved in ./results2/checkpoint-39500/tokenizer_config.json
# Special tokens file saved in ./results2/checkpoint-39500/special_tokens_map.json
# The following columns in the evaluation set don't have a corresponding argument in `BertForSequenceClassification.forward` and have been ignored: sentence, idx. If sentence, idx are not expected by `BertForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 872
#   Batch size = 8
# Saving model checkpoint to ./results2/checkpoint-40000
# Configuration saved in ./results2/checkpoint-40000/config.json
# Model weights saved in ./results2/checkpoint-40000/pytorch_model.bin
# tokenizer config file saved in ./results2/checkpoint-40000/tokenizer_config.json
# Special tokens file saved in ./results2/checkpoint-40000/special_tokens_map.json
# The following columns in the evaluation set don't have a corresponding argument in `BertForSequenceClassification.forward` and have been ignored: sentence, idx. If sentence, idx are not expected by `BertForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 872
#   Batch size = 8
# Saving model checkpoint to ./results2/checkpoint-40500
# Configuration saved in ./results2/checkpoint-40500/config.json
# Model weights saved in ./results2/checkpoint-40500/pytorch_model.bin
# tokenizer config file saved in ./results2/checkpoint-40500/tokenizer_config.json
# Special tokens file saved in ./results2/checkpoint-40500/special_tokens_map.json
# The following columns in the evaluation set don't have a corresponding argument in `BertForSequenceClassification.forward` and have been ignored: sentence, idx. If sentence, idx are not expected by `BertForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 872
#   Batch size = 8
# Saving model checkpoint to ./results2/checkpoint-41000
# Configuration saved in ./results2/checkpoint-41000/config.json
# Model weights saved in ./results2/checkpoint-41000/pytorch_model.bin
# tokenizer config file saved in ./results2/checkpoint-41000/tokenizer_config.json
# Special tokens file saved in ./results2/checkpoint-41000/special_tokens_map.json
# The following columns in the evaluation set don't have a corresponding argument in `BertForSequenceClassification.forward` and have been ignored: sentence, idx. If sentence, idx are not expected by `BertForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 872
#   Batch size = 8
# Saving model checkpoint to ./results2/checkpoint-41500
# Configuration saved in ./results2/checkpoint-41500/config.json
# Model weights saved in ./results2/checkpoint-41500/pytorch_model.bin
# tokenizer config file saved in ./results2/checkpoint-41500/tokenizer_config.json
# Special tokens file saved in ./results2/checkpoint-41500/special_tokens_map.json
# The following columns in the evaluation set don't have a corresponding argument in `BertForSequenceClassification.forward` and have been ignored: sentence, idx. If sentence, idx are not expected by `BertForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Evaluation *****
#   Num examples = 872
#   Batch size = 8
# Saving model checkpoint to ./results2/checkpoint-42000
# Configuration saved in ./results2/checkpoint-42000/config.json
# Model weights saved in ./results2/checkpoint-42000/pytorch_model.bin
# tokenizer config file saved in ./results2/checkpoint-42000/tokenizer_config.json
# Special tokens file saved in ./results2/checkpoint-42000/special_tokens_map.json
#
#
# Training completed. Do not forget to share your model on huggingface.co/models =)
# TrainOutput(global_step=42095, training_loss=0.17279641976873614, metrics={'train_runtime': 4592.3101, 'train_samples_per_second': 73.328, 'train_steps_per_second': 9.166, 'total_flos': 5143865326723080.0, 'train_loss': 0.17279641976873614, 'epoch': 5.0})

# %%
predictions = trainer.predict(tokenized_datasets["validation"])
print(predictions.predictions.shape, predictions.label_ids.shape)
preds = np.argmax(predictions.predictions, axis=-1)

metric = evaluate.load("glue", "sst2")
metric.compute(predictions=preds, references=predictions.label_ids)
# Out:
# The following columns in the test set don't have a corresponding argument in `BertForSequenceClassification.forward` and have been ignored: sentence, idx. If sentence, idx are not expected by `BertForSequenceClassification.forward`,  you can safely ignore this message.
# ***** Running Prediction *****
#   Num examples = 872
#   Batch size = 8
# (872, 2) (872,)
# {'accuracy': 0.8922018348623854}
